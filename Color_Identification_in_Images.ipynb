# %% [markdown]
# # Intern : Namit Jain
#
# # DATA SCIENCE AND BUSINESS ANALYTICS Intern at The Sparks Foundation

# %% [markdown]
# ## ADDITIONAL TASK 1
# ## COMPUTER VISION AND INTERNET OF THINGS
# ## Task 2 : Color Identification in Images

# %% [markdown]
# #### Importing necessary libraries

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import Counter
import os
# %matplotlib inline

# %% [markdown]
# #### Function for converting RGB values to HEX values

# %%
def RGB2HEX(color):
    return "#{:02x}{:02x}{:02x}".format(int(color[0]), int(color[1]), int(color[2]))

# %% [markdown]
# #### Function to read an image and convert it from BGR to RGB

# %%
def get_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    return image

# %% [markdown]
# #### Function to extract colors from an image

# %%
def get_colors(image, number_of_colors, show_chart):
    modified_image = cv2.resize(image, (960, 540), interpolation = cv2.INTER_AREA)
    modified_image = modified_image.reshape(modified_image.shape[0]*modified_image.shape[1], 3)
    clf = KMeans(n_clusters = number_of_colors)
    labels = clf.fit_predict(modified_image)
    counts = Counter(labels)

    center_colors = clf.cluster_centers_
    # We get ordered colors by iterating through the keys
    ordered_colors = [center_colors[i] for i in counts.keys()]
    hex_colors = [RGB2HEX(ordered_colors[i]) for i in counts.keys()]
    rgb_colors = [ordered_colors[i] for i in counts.keys()]

    if (show_chart):
        plt.figure(figsize = (8, 6))
        plt.pie(counts.values(), labels = hex_colors, colors = hex_colors)

    return rgb_colors

# %% [markdown]
# #### Reading first image

# %%
image = get_image('./image1.jpg')
print("The type of this input is {}".format(type(image)))
print("Shape: {}".format(image.shape))
plt.imshow(image)
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (551, 980, 3)

# %% [markdown]
# #### Extracting colors in first image and showing their proportion in Pie Chart

# %%
get_colors(image,10,True)
# Out:
# [array([147.31072225, 189.42583271, 251.40534423]),
#  array([101.99510145, 141.81666435,  27.64205785]),
#  array([240.21068373, 249.17422961, 253.50077223]),
#  array([64.65865721, 96.26665078, 17.66466058]),
#  array([ 70.95201195, 142.81001972, 251.79806507]),
#  array([45.74259717, 74.10580918,  8.51509494]),
#  array([186.61622279, 215.13573021, 251.3439294 ]),
#  array([133.79514918, 178.00130903,  35.34069354]),
#  array([109.29986421, 166.36672073, 251.30182559]),
#  array([ 31.82492237, 116.92800355, 247.89412086])]

# %% [markdown]
# #### Reading second image

# %%
image = get_image('./image2.jpg')
print("The type of this input is {}".format(type(image)))
print("Shape: {}".format(image.shape))
plt.imshow(image)
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (514, 800, 3)

# %% [markdown]
# #### Extracting colors in first image and showing their proportion in Pie Chart

# %%
get_colors(image,10,True)
# Out:
# [array([64.40910266, 58.38650116, 76.99208689]),
#  array([237.05981378, 210.27712737, 131.09906105]),
#  array([237.46910389, 192.71716098,  86.15876289]),
#  array([ 94.98406894, 182.64968474, 214.48541404]),
#  array([193.28437421, 132.24384349, 146.4394659 ]),
#  array([228.4214231 , 140.89042425, 112.5249713 ]),
#  array([158.30130776, 105.54555653, 125.86138644]),
#  array([232.07290232, 231.30044975, 203.31477161]),
#  array([174.95706008, 212.6521347 , 218.4155688 ]),
#  array([24.55451325, 20.36025917, 32.07787607])]

# %% [markdown]
# #### Reading third image

# %%
image = get_image('./image3.jpg')
print("The type of this input is {}".format(type(image)))
print("Shape: {}".format(image.shape))
plt.imshow(image)
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (450, 800, 3)

# %% [markdown]
# #### Extracting colors in third image and showing their proportion in Pie Chart

# %%
get_colors(image,10,True)
# Out:
# [array([ 76.46548087, 170.01719872, 243.03271407]),
#  array([152.39340163,  70.08711785, 109.50590197]),
#  array([117.70628115, 120.07758272, 175.44726799]),
#  array([ 81.35658377, 112.37605271,  14.20735493]),
#  array([  8.92376222, 134.06625955, 234.04714696]),
#  array([196.03822962, 119.63128102, 159.52676484]),
#  array([118.95525808, 148.49297516,  51.31445972]),
#  array([44.7917142 , 65.64655486,  8.18234109]),
#  array([157.560324  , 208.57274615, 244.81128544]),
#  array([114.00118399,  34.59414065,  66.57613305])]

# %% [markdown]
# #### Reading fourth image

# %%
image = get_image('./image4.jpg')
print("The type of this input is {}".format(type(image)))
print("Shape: {}".format(image.shape))
plt.imshow(image)
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (408, 612, 3)

# %% [markdown]
# #### Extracting colors in fourth image and showing their proportion in Pie Chart

# %%
get_colors(image,10,True)
# Out:
# [array([248.13724091, 110.38311442,  68.44604054]),
#  array([146.40766914,  33.61366349, 187.89066556]),
#  array([189.13038058,  87.2397756 , 238.83937043]),
#  array([100.11418829,  94.37451423, 229.84152804]),
#  array([ 48.40531442,  30.3687509 , 152.05131786]),
#  array([195.14602407,  44.88100996, 103.85714286]),
#  array([254.44759183, 194.20154533,  54.95918877]),
#  array([ 66.1010082 , 154.2964159 , 210.53532471]),
#  array([ 75.50894171, 217.92074437, 192.26046896]),
#  array([231.27073313,  92.93253938, 171.69381887])]
